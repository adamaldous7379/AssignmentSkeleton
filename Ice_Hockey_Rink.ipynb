# %%
from PIL import Image, ImageDraw

# base for the rink
width, height = 2023, 870
image = Image.new("RGB", (width, height), "white")
draw = ImageDraw.Draw(image)

# Draw the rounded rectangle
x, y = 0, 0  # Top-left corner coordinates
width, height = 2000, 850  # Width and height of the rectangle
radius = 280  # Radius of the rounded corners
fill_color = "white"  # Color for the circle's interior
outline_color = "red"
draw.rectangle([(x, y + radius), (x + width, y + height - radius)], fill=fill_color, outline="black")
draw.rectangle([(x + radius, y), (x + width - radius, y + height)], fill=fill_color, outline="black")
draw.arc((x, y, x + radius * 2, y + radius * 2), start=180, end=270, fill="black")
draw.arc((x + width - radius * 2, y, x + width, y + radius * 2), start=270, end=360, fill="black")
draw.arc((x, y + height - radius * 2, x + radius * 2, y + height), start=90, end=180, fill="black")
draw.arc((x + width - radius * 2, y + height - radius * 2, x + width, y + height), start=0, end=90, fill="black")

#cleaning up the lines
draw.line([(1,280), (1999,280)], fill="white", width=2)
draw.line([(1,570), (1999,570)], fill="white", width=2)
draw.line([(280,1), (280,849)], fill="white", width=2)
draw.line([(1720,1), (1720,849)], fill="white", width=2)

# referee crease
center = (1000, 850)  # Center coordinates
radius = 100
draw.ellipse([(center[0] - radius, center[1] - radius),(center[0] + radius, center[1] + radius)],fill="white", outline="red", width=2)

# centre ice faceoff circle
center = (width // 2, height // 2)
radius = 150
radius2 = 6
fill_color = "white"  # Color for the circle's interior
outline_color = "red"  # Color for the circle's outline
draw.ellipse([(center[0] - radius, center[1] - radius), (center[0] + radius, center[1] + radius)], fill=fill_color, outline=outline_color, width=2)

# goal lines
draw.line([(112,57.514), (112,794.486)], fill="red", width=2) # left
draw.line([(1888,57.514), (1888,792.486)], fill="red", width=2) # right

# blue lines
draw.line([(750,1),(750,849)],fill="blue",width=10) # left
draw.line([(1250,1),(1250,849)],fill="blue",width=10) # right

#centre line
draw.line([(1000.5,1),(1000.5,849)],fill="red",width=10)
draw.ellipse([(center[0] - radius2, center[1] - radius2), (center[0] + radius2, center[1] + radius2)], fill="red", outline="white", width=1)


# top-left faceoff dot
center = (380, 205) 
radius = 150
draw.ellipse([(center[0] - radius, center[1] - radius),(center[0] + radius, center[1] + radius)],fill=fill_color, outline=outline_color, width=2)
draw.ellipse([(center[0] - radius2, center[1] - radius2),(center[0] + radius2, center[1] + radius2)],fill=outline_color, outline=outline_color, width=1)

# bottom-left faceoff dot
center = (380, 645)  
radius = 150
draw.ellipse([(center[0] - radius, center[1] - radius),(center[0] + radius, center[1] + radius)],fill=fill_color, outline=outline_color, width=2)
draw.ellipse([(center[0] - radius2, center[1] - radius2),(center[0] + radius2, center[1] + radius2)],fill=outline_color, outline=outline_color, width=1)

# top-right faceoff dot
center = (1620, 205)  
radius = 150
draw.ellipse([(center[0] - radius, center[1] - radius),(center[0] + radius, center[1] + radius)],fill=fill_color, outline=outline_color, width=2)
draw.ellipse([(center[0] - radius2, center[1] - radius2),(center[0] + radius2, center[1] + radius2)],fill=outline_color, outline=outline_color, width=1)

# bottom-right faceoff dot
center = (1620, 645)  
radius = 150
draw.ellipse([(center[0] - radius, center[1] - radius),(center[0] + radius, center[1] + radius)],fill=fill_color, outline=outline_color, width=2)
draw.ellipse([(center[0] - radius2, center[1] - radius2),(center[0] + radius2, center[1] + radius2)],fill=outline_color, outline=outline_color, width=1)

# remaining lines and hashmarks to the faceoff circles
draw.line([(369, 199),(369,189)], fill="red", width=2)
draw.line([(391, 199),(391,189)], fill="red", width=2)
draw.line([(369, 639),(369,629)], fill="red", width=2)
draw.line([(391, 639),(391,629)], fill="red", width=2)
draw.line([(1609, 199),(1609,189)], fill="red", width=2)
draw.line([(1631, 199),(1631,189)], fill="red", width=2)
draw.line([(1609, 639),(1609,629)], fill="red", width=2)
draw.line([(1631, 639),(1631,629)], fill="red", width=2)

draw.line([(369, 219),(369,209)], fill="red", width=2)
draw.line([(391, 219),(391,209)], fill="red", width=2)
draw.line([(369, 659),(369,649)], fill="red", width=2)
draw.line([(391, 659),(391,649)], fill="red", width=2)
draw.line([(1609, 219),(1609,209)], fill="red", width=2)
draw.line([(1631, 219),(1631,209)], fill="red", width=2)
draw.line([(1609, 659),(1609,649)], fill="red", width=2)
draw.line([(1631, 659),(1631,649)], fill="red", width=2) 

draw.line([(369, 199),(349,199)], fill="red", width=2)
draw.line([(369, 209),(349,209)], fill="red", width=2)
draw.line([(369, 639),(349,639)], fill="red", width=2)
draw.line([(369, 649),(349,649)], fill="red", width=2)
draw.line([(391, 199),(411,199)], fill="red", width=2)
draw.line([(391, 209),(411,209)], fill="red", width=2)
draw.line([(391, 639),(411,639)], fill="red", width=2)
draw.line([(391, 649),(411,649)], fill="red", width=2)

draw.line([(1609, 199),(1589,199)], fill="red", width=2)
draw.line([(1609, 209),(1589,209)], fill="red", width=2)
draw.line([(1609, 639),(1589,639)], fill="red", width=2)
draw.line([(1609, 649),(1589,649)], fill="red", width=2)
draw.line([(1631, 199),(1651,199)], fill="red", width=2)
draw.line([(1631, 209),(1651,209)], fill="red", width=2)
draw.line([(1631, 639),(1651,639)], fill="red", width=2)
draw.line([(1631, 649),(1651,649)], fill="red", width=2)

draw.line([(369, 57),(369,47)], fill="red", width=2)
draw.line([(392, 57),(392,47)], fill="red", width=2)
draw.line([(369, 366),(369,356)], fill="red", width=2)
draw.line([(392, 366),(392,356)], fill="red", width=2)
draw.line([(1609, 57),(1609,47)], fill="red", width=2)
draw.line([(1639, 57),(1639,47)], fill="red", width=2)
draw.line([(1609, 366),(1609,356)], fill="red", width=2)
draw.line([(1639, 366),(1639,356)], fill="red", width=2)

draw.line([(369, 497),(369,487)], fill="red", width=2)
draw.line([(392, 497),(392,487)], fill="red", width=2)
draw.line([(369, 806),(369,796)], fill="red", width=2)
draw.line([(392, 806),(392,796)], fill="red", width=2)
draw.line([(1609, 497),(1609,487)], fill="red", width=2)
draw.line([(1639, 497),(1639,487)], fill="red", width=2)
draw.line([(1609, 806),(1609,796)], fill="red", width=2)
draw.line([(1639, 806),(1639,796)], fill="red", width=2)

# remaining faceoff dots
center = (800,205)
draw.ellipse([(center[0] - radius2, center[1] - radius2),(center[0] + radius2, center[1] + radius2)],fill=outline_color, outline=outline_color, width=2)
center = (800,645)
draw.ellipse([(center[0] - radius2, center[1] - radius2),(center[0] + radius2, center[1] + radius2)],fill=outline_color, outline=outline_color, width=2)
center = (1200,205)
draw.ellipse([(center[0] - radius2, center[1] - radius2),(center[0] + radius2, center[1] + radius2)],fill=outline_color, outline=outline_color, width=2)
center = (1200,645)
draw.ellipse([(center[0] - radius2, center[1] - radius2),(center[0] + radius2, center[1] + radius2)],fill=outline_color, outline=outline_color, width=2)

# goal creases
draw.ellipse((130, 385, 170, 465), outline="red", fill="blue",width=2) # Left
draw.rectangle((112,385,152,465), fill="blue",outline="red", width=2)
draw.ellipse((1830, 385, 1870, 465), outline="red", fill="blue",width=2) # Right
draw.rectangle((1888,385,1848,465), fill="blue",outline="red", width=2)

# Save the image
image.save("rink.png")

# Show the image
image.show()
img = Image.open("rink.png")
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2023x870>
